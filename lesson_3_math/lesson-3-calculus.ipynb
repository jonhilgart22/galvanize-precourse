# %% [markdown]
# # Lesson 3: Calculus

# %% [markdown]
# ## Functions
# Let's review the 3 main trigonometric functions: sine, cosine, tangent.

# %% [markdown]
# The trigonometric functions are derived from a right triangle by 3 points: the origin (let's call it point A), a point on the x-axis (point B), and a point directly above or below opoint B on the unit circle (point C).
#
# Line segment **AB** is always on the x-axis and draws out the **adjacent** side of the triangle, so its length can take the values between -1 and 1 inclusive.
# Line segment **BC** draw out the **opposite** side, so its length can take the values between -1 and 1 inclusive.
# Line segment **AC** draws out the **hypotenuse**, which always has a length of 1 since we are on the unit circle.
# $\theta$ (called theta) is drawn by angle BAC--basically it's the angle that's always between 0 and 90 degrees (0 and $\frac {\pi} {2}$ radians) created by the hypotenuse and the adjacent side.
# <br>
# In math, we usually do everything using radians instead of degrees. The formula to convert from degrees to radians is: $\pi / 180 * degrees$. Hence, the full length along the circumference of the unit circle is 360 degrees = $360 * \pi / 180 = 2\pi$.
# <br>
#
# $sin(\theta) = \frac {opposite} {hypotenuse}$
# $cos(\theta) = \frac {adjacent} {hypotenuse}$
# $tan(\theta) = \frac {sin(\theta)} {cos(\theta)} = \frac {opposite} {adjacent}$
# <br>
# The less common cofunctions are:
# $cosecant = \frac 1 {sine}$
# $secant = \frac 1  {cosine}$
# $cotangent = \frac 1 {tangent}$

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import math

# %%
x = [element / 100.0 for element in range(-100, 101)]
y_top = [(1 - element ** 2) ** 0.5 for element in x]
y_bottom = [-(1 - element ** 2) ** 0.5 for element in x]
triangle_x_coordinates = [0.0, 0.6, 0.6, 0.0]
triangle_y_coordinates = [0.0, 0.0, 0.8, 0.0]
coordinate_labels = ['A', 'B', 'C']

fig = plt.figure(figsize=(7, 7))
ax = fig.add_subplot(111)
ax.set_xlim(-1.5, 1.5)
ax.set_ylim(-1.5, 1.5)

plt.plot(x, y_top, c='blue')
plt.plot(x, y_bottom, c='blue')
plt.axvline(x=0)
plt.axhline(y=0)
plt.plot(triangle_x_coordinates, triangle_y_coordinates, c='green')
for x, y, label in zip(triangle_x_coordinates, 
                            triangle_y_coordinates, coordinate_labels): 
    plt.text(x, y, label)
plt.title("Unit Circle");

# %%
# sine: periodicity of 2 * pi
x = [element / 100.0 for element in range(-314, 314)]
y = [math.sin(element) for element in x] # notice that Python computes in radians, not degrees.
plt.plot(x, y)
plt.axvline(x=0)
plt.axhline(y=0)
plt.title("Sine");

# %%
# cosine: periodicity of 2 * pi
x = [element / 100.0 for element in range(-314 / 2, 314 * 3 / 2)]
y = [math.cos(element) for element in x]
plt.plot(x, y)
plt.axvline(x=0)
plt.axhline(y=0)
plt.title("Cosine");

# %%
# tangent: periodicity of pi
x = [element / 100.0 for element in range(-312 / 2, 312 / 2)]
y = [math.tan(element) for element in x]
plt.plot(x, y)
plt.axvline(x=0)
plt.axhline(y=0)
plt.title("Tangent");

# %% [markdown]
# ## Limits
#
# If $f(x)$ gets closer and closer to a number $l$ as $x$ gets closer and closer to $c$ from both sides, then $l$ is the limit of $f(x)$ as $x$ approaches $c$. This behavior is expressed symbolically as:
#
# $$ \lim_{x\rightarrow c} f(x) = l$$
#
# For us to say that $f(x)$ approaches $l$ as $x$ approaches $c$ it *must* be true that the function approaches $l$ from both the $c+$ (right) and $c-$ (left) directions at the value $x$:
#
# $$\lim_{x\rightarrow c+} f(x) = l$$
#
# $$\lim_{x\rightarrow c-} f(x) = l$$
#
# If it doesn't, then the function is *discontinuous* and cannot be differentiated at $x$.
#
# Following are graphs of two functions, $y=f(x)$, that do not have a limit as $x$ approaches 0. The limit does not exist in Figure (a) because $y$ tends toward $1$ as $x$ approaches $0$ from the right and tends toward a different value, $-1$, as $x$ approaches $0$ from the left.
#
# The function in Figure (b) has no finite limit as $x$ approaches $0$ because the values of $y$ increase without bound as $x$ tends toward $0$ and hence tend to no finite number $l$.
#
# |(a)|(b)|
# |---|---|
# |![](./imgs/7.1-discontinuous_limit.png)|![](imgs/7.1-infinite_limit.png)|

# %% [markdown]
# Let's take a simple example: $y = f(x) = x + 1$:
#
# The limit approaching $x = 1$ from the left side is: $\lim_{x \rightarrow 1^{-}} f(x) = 2$ because $f(0.9999) = 1.9999$
# The limit approaching $x = 1$ from the right side is: $\lim_{x \rightarrow 1^{+}} f(x) = 2$ because $f(1.0001) = 2.0001)$
# Since $\lim_{x \rightarrow 1^{-}} f(x) = \lim_{x \rightarrow 1^{+}} f(x) = 2$, then $\lim_{x \to 1} f(x) = 2$
# In words, if left and right-handed limits converge to the same value, then the (unconditional) limit also exists: $\lim_{x \to 1} f(x) = 2$.

# %%
x = range(-3, 4)
y = [element + 1 for element in x]
plt.plot(x, y)
plt.plot([1], [2], marker='o', c='black', markersize=15)
plt.axvline(x=0)
plt.axhline(y=0);

# %% [markdown]
# The interesting thing happens when you hit a discontinuity, a hole, in a function.
# Suppose you have the $f(x) = \frac {(x - 2)(x + 1)} {x - 2}$. The graph will look almost identicaly as the one above except that there exists a hole at x = 2 where the y-value is undefined.
# <br>
# What is the limit of this new function ($f(x) = \frac {(x - 2)(x + 1)} {x - 2}$) as $x$ approaches 2?
# The limit approaching $x = 2$ from the left side is: $\lim_{x \rightarrow 2^{-}} f(x) = 3$ because we never land on $x$ but approach $x = 2$ from the left side. For example, $f(1.9999)$ exists and equals 2.9999.
# The limit approaching $x = 2$ from the right side is: $\lim_{x \rightarrow 2^{+}} f(x) = 3$ because we never land on $x$ but approach $x = 2$ from the left side. For example, $f(2.0001)$ exists and equals 3.0001.
# Since $\lim_{x \rightarrow 2^{-}} f(x) = \lim_{x \rightarrow 2^{+}} f(x) = 3$, then $\lim_{x \to 2} f(x) = 3$
# Notice that although $f(2)$ does not exist, $\lim_{x \to 2} f(x)$ exists and equals 3. Despite the discontinuity at that point where $f(2)$ does not exist, the limit nonethless still exists.

# %%
x = range(-3, 4)
y = [element + 1 for element in x]
plt.plot(x, y)
plt.plot(2, 3, marker='o', c='white', markersize=15) #hole here
plt.axvline(x=0)
plt.axhline(y=0);

# %% [markdown]
# Now let's that a look at Python's $\it{int}$ function. It's a step function that cuts off all the numbers after the decimal point in a number. Basically, $f(x)$ = round x down to lower integer
# What is the limit of $\lim_{x \to 2} f(x)?$
#
# $\lim_{x \rightarrow 2^{-}} f(x) = 1$
# $\lim_{x \rightarrow 2^{+}} f(x) = 2$
# $\lim_{x \rightarrow 2^{-}} f(x) \neq \lim_{x \rightarrow 2^{+}} f(x)$
# Therefore $\lim_{x \to 2} f(x)$ does not exist--no solution.

# %%
x1 = [element / 100.0 for element in range(100)]
x2 = [element / 100.0 for element in range(100, 200)]
x3 = [element / 100.0 for element in range(200, 300)]
y1 = [int(element) for element in x1]
y2 = [int(element) for element in x2]
y3 = [int(element) for element in x3]
plt.plot(x1, y1)
plt.plot(x2, y2)
plt.plot(x3, y3)
plt.ylim(-0.5, 2.5)
plt.title("Step Function");

# %% [markdown]
# #### Some Properties of Limits
#
# The limit of a constant is the constant itself, and the limit of $f (x) = x$ as $x$ approaches $c$ is $c$, i.e.,
#
# $$\lim_{x \rightarrow c} k = k ~~~~~~ \text{and} ~~~~~~ \lim_{x \rightarrow c} x = c$$
#
# Following are certain algebraic rules obeyed by limits that can be used to simplify computations:
#
# If $\lim_{x \rightarrow c} f(x)$ and $\lim_{x \rightarrow c} g(x)$ exist, then
#
# $$\lim_{x\rightarrow c} [k f(x)] = k \lim_{x\rightarrow c} f(x) ~~~~~ \text{for any constant }k$$
#
# $$\lim_{x\rightarrow c} [f(x) \pm g(x)] = \lim_{x\rightarrow c} f(x) \pm \lim_{x\rightarrow c} g(x)$$
#
# $$\lim_{x\rightarrow c} [f(x) g(x)] = [\lim_{x\rightarrow c} f(x)] [\lim_{x\rightarrow c} g(x)]$$
#
# $$\lim_{x\rightarrow c} [f(x)]^p = [\lim_{x\rightarrow c} f(x)]^p ~~~~~~~~ \text{if }\lim_{x\rightarrow c} f(x)\text{ exists.}$$

# %% [markdown]
# #### Your turn: Practice Problems
#
# 1. $\lim_{x \rightarrow c} ax+b$
# 2. $\lim_{x \rightarrow 4} \dfrac{x^2-1}{x+1}$
# 3. Is the function $f(n) = \begin{cases} 0 &\mbox{if } x < 2 \\
# 1 & \mbox{if } x \geq 2. \end{cases}$ continuous and differentiable over all $x$? How about at $x=2$?

# %% [markdown]
# ## Derivatives
#
# ##### A Tour De Force of Basic Calculus
#
# There are two essential tools that we need to have so we can arrive at calculus: The **derivative taken by limit** and the **Riemann intgral.** The story of the Riemann integral is one of the most compelling in mathematical history. Derivatives and integrals were known and studied (and used!) for *hundreds of years* before anyone came up with accurate definitions of them.
#
# We begin with the basic concept of a difference equation.
#
# #### Differences and slopes in a linear function
#
# Let's define a linear function of the form
#
# $$f(x) = m x + c$$
#
# The graph of this function is a straight line, such that:
#
# 1. $m$ is the slope, or rate of change of y with respect to $x$.
# 2. $c$ is the vertical intercept, or value of $y$ when $x$ is zero.
#
# <img src="imgs/7.1-linear_graph.png" width=400>
#
# The slope, $m$, is given by the mnemonic **rise** over **run**.
#
# $$m = \frac{rise}{run} = \frac{\Delta y}{\Delta x} = \frac{f(x_2)-f(x_1)}{x_2-x_1}$$
#
#
# We use the symbol $\Delta$ (capital delta) to mean "change in", so $\Delta x$ means change in $x$ and $\Delta y$ means change in $y$.

# %% [markdown]
# This is all very nice, but there are many (if not most) functions that are highly valuable whose slope is not always constant. Therefore the **slope is dependent on the value of the independent variable** and hence the **slope itself is also a function of the independent variable.**
#
# In order to find the slope of these functions we must find a mathematical object called the **limit**.

# %% [markdown]
# ## Integrals
