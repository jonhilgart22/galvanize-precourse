# %% [markdown]
# # Lesson 3: Calculus
#
# ### A Tour De Force of Basic Calculus
# More resources: http://tutorial.math.lamar.edu/Classes/CalcI/CalcI.aspx
#
# There are two essential tools that we need to have so we can arrive at calculus: The **derivative** (taken by limit) and the (Riemann) **intgral.** The story of the Riemann integral is one of the most compelling in mathematical history. Derivatives and integrals were known and studied (and used!) for *hundreds of years* before anyone came up with accurate definitions of them.

# %% [markdown]
# ## Review of Trigonometric Functions
# More resoures: http://tutorial.math.lamar.edu/Classes/CalcI/TrigFcns.aspx
#
# Let's review the 3 main trigonometric functions: sine, cosine, tangent.
# The trigonometric functions are derived from a right triangle by 3 points: the origin (let's call it point A), a point on the x-axis (point B), and a point directly above or below opoint B on the unit circle (point C).
#
# Line segment **AB** is always on the x-axis and draws out the **adjacent** side of the triangle, so its length can take the values between -1 and 1 inclusive.
# Line segment **BC** draw out the **opposite** side, so its length can take the values between -1 and 1 inclusive.
# Line segment **AC** draws out the **hypotenuse**, which always has a length of 1 since we are on the unit circle.
# $\theta$ (called theta) is drawn by angle BAC--basically it's the angle that's always between 0 and 90 degrees (0 and $\frac {\pi} {2}$ radians) created by the hypotenuse and the adjacent side.
# <br>
# In math, we usually do everything using radians instead of degrees. The formula to convert from degrees to radians is: $\pi / 180 * degrees$. Hence, the full length along the circumference of the unit circle is 360 degrees = $360 * \pi / 180 = 2\pi$.
# <br>
#
# $sin(\theta) = \frac {opposite} {hypotenuse}$
# $cos(\theta) = \frac {adjacent} {hypotenuse}$
# $tan(\theta) = \frac {sin(\theta)} {cos(\theta)} = \frac {opposite} {adjacent}$
# <br>
# The less common cofunctions are:
# $cosecant = \frac 1 {sine}$
# $secant = \frac 1  {cosine}$
# $cotangent = \frac 1 {tangent}$

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import math

# %%
x = [element / 100.0 for element in range(-100, 101)]
y_top = [(1 - element ** 2) ** 0.5 for element in x]
y_bottom = [-(1 - element ** 2) ** 0.5 for element in x]
triangle_x_coordinates = [0.0, 0.6, 0.6, 0.0]
triangle_y_coordinates = [0.0, 0.0, 0.8, 0.0]
coordinate_labels = ['A', 'B', 'C']

fig = plt.figure(figsize=(7, 7))
ax = fig.add_subplot(111)
ax.set_xlim(-1.5, 1.5)
ax.set_ylim(-1.5, 1.5)

plt.plot(x, y_top, c='blue')
plt.plot(x, y_bottom, c='blue')
plt.axvline(x=0)
plt.axhline(y=0)
plt.plot(triangle_x_coordinates, triangle_y_coordinates, c='green')
for x, y, label in zip(triangle_x_coordinates, 
                            triangle_y_coordinates, coordinate_labels): 
    plt.text(x, y, label)
plt.title("Unit Circle");

# %%
# sine: periodicity of 2 * pi
x = [element / 100.0 for element in range(-314, 314)]
y = [math.sin(element) for element in x] # notice that Python computes in radians, not degrees.
plt.plot(x, y)
plt.axvline(x=0)
plt.axhline(y=0)
plt.title("Sine");

# %%
# cosine: periodicity of 2 * pi
x = [element / 100.0 for element in range(-314 // 2, 314 * 3 // 2)] # / is float division, // is integer division
y = [math.cos(element) for element in x]
plt.plot(x, y)
plt.axvline(x=0)
plt.axhline(y=0)
plt.title("Cosine");

# %%
# tangent: periodicity of pi
x = [element / 100.0 for element in range(-312 // 2, 312 // 2)]
y = [math.tan(element) for element in x]
plt.plot(x, y)
plt.axvline(x=0)
plt.axhline(y=0)
plt.title("Tangent");

# %% [markdown]
# #### Your turn:
# 1. Plot cosecant of x (csc(x)).
# 2. Plot secant of x (sec(x)).
# 3. Plot cotangent of x (cot(x)).

# %%
#Number one
from mpmath import *

# x = [x for x in range(1,100)]
# y = [y*csc(y) for y in x]
# plt.plot(x,y)

#cosecant = 1/sine
plt.figure()
a = [x for x in range(1,100)]
b = [y*(1/sin(y)) for y in x]
plt.plot(a,b)
plt.title("cosecant")


#Number two
plt.figure()
r = [x for x in range(1,100)]
f = [y*(1/cos(y)) for y in x]
plt.plot(r,f)
plt.title('secant')

#Number three

plt.figure()
q = [x for x in range(1,100)]
s = [y*(1/tan(y)) for y in x]
plt.plot(q,s)
plt.title('Cotangent')

# %% [markdown]
# ## Limits
#
# More resources: http://tutorial.math.lamar.edu/Classes/CalcI/LimitsIntro.aspx
#
# If $f(x)$ gets closer and closer to a number $l$ as $x$ gets closer and closer to $c$ from both sides, then $l$ is the limit of $f(x)$ as $x$ approaches $c$. This behavior is expressed symbolically as:
#
# $$ \lim_{x\rightarrow c} f(x) = l$$
#
# For us to say that $f(x)$ approaches $l$ as $x$ approaches $c$ it *must* be true that the function approaches $l$ from both the $c+$ (right) and $c-$ (left) directions at the value $x$:
#
# $$\lim_{x\rightarrow c+} f(x) = l$$
#
# $$\lim_{x\rightarrow c-} f(x) = l$$
#
# If it doesn't, then the function is *discontinuous* and cannot be differentiated at $x$.
#
# Following are graphs of two functions, $y=f(x)$, that do not have a limit as $x$ approaches 0. The limit does not exist in Figure (a) because $y$ tends toward $1$ as $x$ approaches $0$ from the right and tends toward a different value, $-1$, as $x$ approaches $0$ from the left.
#
# The function in Figure (b) has no finite limit as $x$ approaches $0$ because the values of $y$ increase without bound as $x$ tends toward $0$ and hence tend to no finite number $l$.
#
# |(a)|(b)|
# |---|---|
# |![](./imgs/7.1-discontinuous_limit.png)|![](imgs/7.1-infinite_limit.png)|

# %% [markdown]
# Let's take a simple example: $y = f(x) = x + 1$:
#
# The limit approaching $x = 1$ from the left side is: $\lim_{x \rightarrow 1^{-}} f(x) = 2$ because $f(0.9999) = 1.9999$
# The limit approaching $x = 1$ from the right side is: $\lim_{x \rightarrow 1^{+}} f(x) = 2$ because $f(1.0001) = 2.0001)$
# Since $\lim_{x \rightarrow 1^{-}} f(x) = \lim_{x \rightarrow 1^{+}} f(x) = 2$, then $\lim_{x \to 1} f(x) = 2$
# In words, if left and right-handed limits converge to the same value, then the (unconditional) limit also exists: $\lim_{x \to 1} f(x) = 2$.

# %%
x = range(-3, 4)
y = [element + 1 for element in x]
plt.plot(x, y)
plt.plot([1], [2], marker='o', c='black', markersize=15)
plt.axvline(x=0)
plt.axhline(y=0);

# %% [markdown]
# The interesting thing happens when you hit a discontinuity, a hole, in a function.
# Suppose you have the $f(x) = \frac {(x - 2)(x + 1)} {x - 2}$. The graph will look almost identicaly as the one above except that there exists a hole at x = 2 where the y-value is undefined.
# <br>
# What is the limit of this new function ($f(x) = \frac {(x - 2)(x + 1)} {x - 2}$) as $x$ approaches 2?
# The limit approaching $x = 2$ from the left side is: $\lim_{x \rightarrow 2^{-}} f(x) = 3$ because we never land on $x$ but approach $x = 2$ from the left side. For example, $f(1.9999)$ exists and equals 2.9999.
#
# The limit approaching $x = 2$ from the right side is: $\lim_{x \rightarrow 2^{+}} f(x) = 3$ because we never land on $x$ but approach $x = 2$ from the left side. For example, $f(2.0001)$ exists and equals 3.0001.
#
# Since $\lim_{x \rightarrow 2^{-}} f(x) = \lim_{x \rightarrow 2^{+}} f(x) = 3$, then $\lim_{x \to 2} f(x) = 3$
# Notice that although $f(2)$ does not exist, $\lim_{x \to 2} f(x)$ exists and equals 3. Despite the discontinuity at that point where $f(2)$ does not exist, the limit nonethless still exists.

# %%
x = range(-3, 4)
y = [element + 1 for element in x]
plt.plot(x, y)
plt.plot(2, 3, marker='o', c='white', markersize=15) #hole here
plt.axvline(x=0)
plt.axhline(y=0);

# %% [markdown]
# Now let's that a look at Python's $\it{int}$ function. It's a step function that cuts off all the numbers after the decimal point in a number. Basically, $f(x)$ = round x down to lower integer
# What is the limit of $\lim_{x \to 2} f(x)?$
#
# $\lim_{x \rightarrow 2^{-}} f(x) = 1$
# $\lim_{x \rightarrow 2^{+}} f(x) = 2$
# $\lim_{x \rightarrow 2^{-}} f(x) \neq \lim_{x \rightarrow 2^{+}} f(x)$
# Therefore $\lim_{x \to 2} f(x)$ does not exist--no solution.

# %%
x1 = [element / 100.0 for element in range(100)]
x2 = [element / 100.0 for element in range(100, 200)]
x3 = [element / 100.0 for element in range(200, 300)]
y1 = [int(element) for element in x1]
y2 = [int(element) for element in x2]
y3 = [int(element) for element in x3]
plt.plot(x1, y1)
plt.plot(x2, y2)
plt.plot(x3, y3)
plt.ylim(-0.5, 2.5)
plt.title("Step Function");

# %% [markdown]
# #### Some Properties of Limits
#
# The limit of a constant is the constant itself, and the limit of $f (x) = x$ as $x$ approaches $c$ is $c$, i.e.,
#
# $$\lim_{x \rightarrow c} k = k ~~~~~~ \text{and} ~~~~~~ \lim_{x \rightarrow c} x = c$$
#
# Following are certain algebraic rules obeyed by limits that can be used to simplify computations:
#
# If $\lim_{x \rightarrow c} f(x)$ and $\lim_{x \rightarrow c} g(x)$ exist, then
#
# $$\lim_{x\rightarrow c} [k f(x)] = k \lim_{x\rightarrow c} f(x) ~~~~~ \text{for any constant }k$$
#
# $$\lim_{x\rightarrow c} [f(x) \pm g(x)] = \lim_{x\rightarrow c} f(x) \pm \lim_{x\rightarrow c} g(x)$$
#
# $$\lim_{x\rightarrow c} [f(x) g(x)] = [\lim_{x\rightarrow c} f(x)] [\lim_{x\rightarrow c} g(x)]$$
#
# $$\lim_{x\rightarrow c} [f(x)]^p = [\lim_{x\rightarrow c} f(x)]^p ~~~~~~~~ \text{if }\lim_{x\rightarrow c} f(x)\text{ exists.}$$

# %% [markdown]
# #### Your turn: Practice Problems
#
# 1. $\lim_{x \rightarrow c} ax+b$
# 2. $\lim_{x \rightarrow 4} \dfrac{x^2-1}{x+1}$
# 3. Is the function $f(n) = \begin{cases} 0 &\mbox{if } x < 2 \\
# 1 & \mbox{if } x \geq 2. \end{cases}$ continuous and differentiable over all $x$? How about at $x=2$?
# 4. $\lim_{x \rightarrow \frac {\pi} {2} ^{-}} tan(x)$
# 5. $\lim_{x \rightarrow \frac {\pi} {2} ^{+}} tan(x)$
# 6. Does $\lim_{x \rightarrow \frac {\pi} {2}} tan(x)$ exist?

# %%
#Practice problems

"1) a * c +b "
"2) lim = 3"
"3) This function is discountinuous and not differentiable over all x. This function is discountinuous at x=2 \
because lim approaching from the left = 0 and lim approaching from the right = 1"
"4) lim = - negative infinity"
"5) lim = + infinity"
"6) tan(pi/2)  = sin(pi/2)/  cos(pi/2) , cos(pi/2) = 0 , undefined"
# Out:
# '6) tan(pi/2)  = sin(pi/2)/  cos(pi/2) , cos(pi/2) = 0 , undefined'

# %% [markdown]
# ## Derivatives
# More resources: http://tutorial.math.lamar.edu/Classes/CalcI/DerivativeIntro.aspx
#
# We begin with the basic concept of a difference equation.
#
# #### Differences and slopes in a linear function
#
# Let's define a linear function of the form
#
# $$f(x) = m x + c$$
#
# The graph of this function is a straight line, such that:
#
# 1. $m$ is the slope, or rate of change of y with respect to $x$.
# 2. $c$ is the vertical intercept, or value of $y$ when $x$ is zero.
#
# <img src="imgs/7.1-linear_graph.png" width=400>
#
# The slope, $m$, is given by the mnemonic **rise** over **run**.
#
# $$m = \frac{rise}{run} = \frac{\Delta y}{\Delta x} = \frac{f(x_2)-f(x_1)}{x_2-x_1}$$
#
#
# We use the symbol $\Delta$ (capital delta) to mean "change in", so $\Delta x$ means change in $x$ and $\Delta y$ means change in $y$.
#
#
# This is all very nice, but there are many (if not most) functions that are highly valuable whose slope is not always constant. Therefore the **slope is dependent on the value of the independent variable** and hence the **slope itself is also a function of the independent variable.**
#
# In order to find the slope of these functions we must find use the **limit**! What is the slope of the tangent line for a given x?

# %% [markdown]
# **The slope of any function is the rate of change of the function with respect to itself at a given point.**
#
# The derivative of a function $f$ is a function $f'$ that gives the slope of the tangent line to the graph of $f$ at any point $(x, f(x))$:
#
# ![](imgs/7.2-tangent.png)
#
# The derivative of a function $y=f(x)$ with respect to $x$ at a given $x$ is defined as:
# $$f'(x) = \lim_{\Delta x \rightarrow 0} \frac{f(x + \Delta x) - f(x)}{\Delta x}$$
# provided the limit exists (check that the right and left-handed limits evaluate to the same number). This limit is also called the _instantaneous rate of change_ (or simple, the _rate of change_) of $y$ with respect to $x$ for a given $x$.
#
#
# If the limit exists, then the function $f$ is said to be _differentiable_. The derivative is also denoted by $\frac{dy}{dx}$

# %% [markdown]
# #### Example:
#
# Find the derivative of $y=f(x)=x^2 + 3x$ with respect to $x$. Use this to find the value of the derivative at $x=2$
#
# $$y=f(x)=x^2 + 3x$$
#
#
# $$y+\Delta y = f(x+\Delta x) = (x+\Delta x)^2 + 3(x + \Delta x)$$
# $$~~~~~ = x^2 + 2 x \Delta x + (\Delta x)^2 + 3 x + 3 \Delta x$$
# <br>
# $$ \text{implies }\Delta y = f(x+\Delta x) - f(x) = 2 x \Delta x + 3 \Delta x + (\Delta x)^2 \text{ since y = f(x)} $$
#
#
#
# $$\frac{\Delta y}{\Delta x} = {2 x + 3 + \Delta x}$$
#
# Thus the derivative with respect to (w.r.t) $x$ is
#
# $$f'(x) = \lim_{\Delta x \rightarrow 0} \frac{\Delta y}{\Delta x} = \lim_{\Delta x \rightarrow 0} (2 x + 3 + \Delta x) = 2x  + 3$$

# %% [markdown]
# ### Some Properties of the Derivative
#
# #### Derivative of a Constant
#
# The derivative of a constant function is equal to zero:
# $$\frac{d}{dx}[c] = 0$$
#
# You can see this by considering the graph of a constant function $f(x)=c$, which is a horizontal line. Since the slope of such a line is $0$ at all its points, it follows that $f'(x)=0$.
#
# #### The Power Rule
#
# If $n$ is any real number, then the derivative of $f(x) = x^n$ is
#
# $$\frac{d}{dx}[x^n] = n x^{n-1}$$
#
# _Examples_:
# a. If $f(x) = x$, then $f'(x) = \frac{d}{dx}(x) = 1 x^{1-1} = x^0 = 1$
# b. If $f(x) = x^6$, then $f'(x) = \frac{d}{dx}(x^6) = 6 x^{6-1} = 6x^5$
# c. If $f(x) = x^{5/2}$, then $f'(x) = \frac{d}{dx}(x^{5/2}) = \frac{5}{2} x^{3/2}$
#
# #### The Sum Rule
#
# The derivative of the sum (difference) of two differentiable functions is equal to the sum (difference) of their derivatives. This result may be extended to the sum and difference of any finite number of functions:
#
# $$\frac{d}{dx}[f(x) \pm g(x)] = \frac{d}{dx}[f(x)] \pm \frac{d}{dx}[g(x)]$$
#
# _Example_:
# The derivative of $f(x) = 5 x^2 + 3 x + 2$:
# $$\frac{d}{dx}(5 x^2 + 3 x + 2) = \frac{d}{dx}(5 x^2) + \frac{d}{dx}(3 x) + \frac{d}{dx}(2) = 10x + 3 + 0$$

# %% [markdown]
# #### Product Rule
# Suppose you have 2 functions again ($f(x)$ and $g(x)$). What is the derivative of the _product_ of the 2 functions ($f(x)*g(x)$)--hence the term Product Rule?
# It will be the sum of the derivative of the first function multiplied by the second function plus the first function multiplied by the derivative of the second function. It doesn't matter which term comes first since addition is commutative.
# $$\frac{d}{dx}[f(x)*g(x)] = f'(x)*g(x) + f(x)*g'(x)$$
#
# _Example_:
# $\frac{d}{dx}[sin(x)*cos(x)] = cos(x)*cos(x) + sin(x)*(-1)*sin(x) = cos^2(x) - sin^2(x)$
#
# #### Quotient Rule
# Now, a natural corrolary of the product rule is the quotient rule. What is the derivative of the _quoteint_ of the 2 functions ($f(x)/g(x)$)?
# The answer is:
# $$\frac{d}{dx} \frac {f(x)} {g(x)} = \frac {f'(x)*g(x) - f(x)*g'(x)} {g(x)^2}$$
# Notice, here the order of terms in the numerator matters since subtraction is not commutative. Personally, I never memorize this rule since I use the product rule to derive the quotient rule. Think of quotients this way. The answer simplies to the quotient rule:
# $$\frac{d}{dx} [f(x)*{g(x)}^{-1}] = f'(x)*{g(x)}^{-1} + f(x)*\frac{d}{dx} [g(x)^{-1}] = f'(x)*{g(x)}^{-1} + f(x)*[-1 * {g(x)}^{-2}*g'(x)]$$
#
# _Example_:
# $\frac{d}{dx} tan(x) = \frac{d}{dx} \frac {sin(x)} {cos(x)} = \frac {cos(x)*cos(x) - sin(x)*[-1*sin(x)]} {cos^2(x)} = \frac {cos^2(x) + sin^2(x)} {cos^2(x)} = \frac 1 {cos^2(x)} = sec^2(x)$

# %% [markdown]
# #### Chain Rule
#
# Derivatives can help us get around the issue of domains and ranges a bit.
# Suppose $f(x) = \sqrt{x^2 + 1}$ and $g(x) = 2x + 1$, and we have
#
# $$y = f(g(x)) = \sqrt{(2x+1)^2 + 1}$$
#
# If $f$ and $g$ are differentiable, then so is the _composite_ function. The derivative of the composite function can be obtained using _chain rule_:
#
# If $y=f(u)$ is a differentiable function of $u$ and $u=g(x)$ is in turn a differentiable function of  $x$, then the composite function $y=f(g(x))$ is a differentiable function of $x$ whose derivative is given by the product
#
# $$\frac{dy}{dx} = \frac{dy}{du}\frac{du}{dx}$$
#
#
# or, equivalently, by
#
# $$\frac{dy}{dx} = f'(g(x)) g'(x)$$
#
#
# _Example_:
# We want to find the derivative of the function:
#
# $$y=f(x) = (x^2+2)^2 - 3 (x^2+2) + 1$$
#
# Note that $y = u^2 - 3 u + 1$, where $u = x^2 + 2$. Thus
#
# $$ \frac{dy}{du} = 2 u - 3 ~~~~~~~~~ \text{and}~~~~~~~~~~ \frac{du}{dx} = 2x$$
#
# and according to the chain rule:
#
# $$\frac{dy}{dx} = \frac{dy}{du}\frac{du}{dx} = (2u-3)(2x) = [2(x^2+2) - 3](2x) = 2x(2x^2+1)$$

# %% [markdown]
# #### Conceptual Insight
#
# The key aspect of the chain rule is that *rates of change multiply.* To illustrate, suppose that your salary increases twice as fast as your friend's. If your friend's salary increases \$4000 per year, your salary will increase at the rate of 2$\times$4000 or \$8000 per year. In terms of derivatives,
#
# $$\frac{d(\text{your salary})}{dt} = \frac{d(\text{your salary})}{d(\text{friend's salary})} \times \frac{d(\text{friend's salary})}{dt}$$
#
# $$ $8000/\text{yr} = 2 \times $4000/\text{yr}$$
#
# As another example, imagine a circle whose radius increases at a rate of $3~cm/s$. We can find the rate at which the area is increasing using the chain rule:
#
# $$\frac{dA}{dt} = \frac{dA}{dr} \frac{dr}{dt}$$
#
# We're given the rate $dr/dt$, namely $dr/dt = 3~cm/s$. To compute $dA/dr$, we use the formula for the area of the circle, $A = \pi r^2$.
#
# $$\frac{dA}{dr} = \frac{d}{dr}(\pi r^2) = 2\pi r$$
#
#
# Because, $dr/dt = 3~cm/s$, we obtain
#
# $$\frac{dA}{dt} = (2\pi r)(3) = 6\pi r ~ cm^2/s$$

# %% [markdown]
# #### Interesting Cases:
# _Derivative of e to a function of x_:
# We know that the derivative of any constant equals 0. Thus, the derivative of e (natural number) is 0. But what is the derivative of e (natural number) to the power of some function of x? The answer is itself multiplied by the derivative of f(x):
# $$\frac d {dx} e^{f(x)} = e^{f(x)}*f'(x)$$
#
# _Examples_:
# a. $\frac d {dx} e^{x} = e^x*\frac d {dx}x = e^x * 1 = e^{x}$
# Yes, you read that right! The derivative of $e^x$ is just itself. Very interesting.
# b. $\frac d {dx} e^{-3x^2} = e^{-3x^2}*\frac d {dx}(-3x^2) = e^{-3x^2} * (-6x)$
# c. What is the derivative of $2^x$?
# Convert from base 2 to base e first. We know that $e ^ {ln(x)} = x$, so $e ^ {ln(2)} = 2$. Then, $2^x = e ^ {{ln(2)} ^ x}$. ($e$ to the power of $ln(2)$ to the power of $x$)
# Using the rule of exponents ($x ^ {a ^ b} = x ^ {ab}$),  $e ^ {{ln(2)} ^ x} = e ^ {xln(2)}$
# Take the derivative $\frac d {dx} e ^ {xln(2)} = e ^ {xln(2)}*\frac d {dx}[xln(2)] = e ^ {xln(2)} * ln(2) = 2^x * ln(2)$ (Final answer)
# Hence for any constant k, derivative of $k ^ x = k ^ x * ln(k)$
# <br>
# <br>
#
# _Derivative of natural logarithms_:
# Suppose, we want to take the derivative of $ln(f(x))$. The answer is f'(x) / f(x).
# $$\frac d {dx} ln(f(x)) = \frac {f'(x)} {f(x)}$$
# _Examples_:
# a. $\frac d {dx} ln(x) = \frac {\frac d {dx} x } x = \frac 1 x $
# b. $\frac d {dx} ln(cos(x)) = \frac {\frac d {dx} cos(x) } {cos(x)} = \frac {-sin(x)} {cos(x)} $
# c. $\frac d {dx} ln(ln(x)) = \frac {\frac d {dx} ln(x) } {ln(x)} = \frac {\frac 1 x} {ln(x)} = \frac 1 {x*ln(x)}$
# d. $\frac d {dx} log(x)$.
# Since the base is not mentioned, then it will be base 10. Convert to natural log. $log(x) = \frac {ln(x)} {ln(10)}$
# Now take the derivative, $\frac d {dx} \frac {ln(x)} {ln(10)} = \frac 1 {ln(10)} \frac d {dx} ln(x)$  (notice ln(10) is just a constant) $ = \frac 1 {ln(10)} * \frac 1 x = \frac 1 {x*ln(10)}$
# Notice, for any constant k, $\frac d {dx} \log_k x = \frac 1 {x * ln(k)}$

# %% [markdown]
# #### Your turn: Practice Problems
#
# 1. $g(x) = 4x^2$. What is the derivative of $g(x)$?
# 2. $f(x) = e^{cos(x)}$. What is the derivative of $f(x)$?
# 3. $h(x) = f \circ g = e^{cos(4x^2)}$. What is the derivative of this composite function $h(x)$?
# 4. Suppose $f(x) = \infty$, what is the derivative of $f(x)$?
# 5. $f(x) = 2 ^ {3x}$. What is the derivative of $f(x)$?
# 6. $g(x) = ln(tan(x))$. What is the derivative of $g(x)$?
# 7. The cost of producing $x$ units of a particular commodity is $C(x) = \frac{1}{3}x^2 + 4x + 53$ dollars, and the production level $t$ hours into a particular produciton run is $x(t) = 0.2 t^2 + 0.03 t$ units. At what rate is cost changing with respect to time after 4 hours?
# Hint: Basically, this is the same type of question as the previous one. What is $\frac{dC}{dt} = \frac{dC}{dx} \frac{dx}{dt}$ at $t = 4$?

# %%
"1) g'(x) = 8x"
"2) e ^ cos(x) * -sinx(x)"
"3)ln(h(k)) = cos(4x^2)  = -sin(4x^2)*(8x)*e^cos(4x^2)"
"4)undefined"
"5) e^ln(2)^3x  = e^3x*ln(2) = [e^3x*ln(2) ] *3(ln(2)) = 2^3x * (3*ln(2)) "
"6)dx/dy  ln(tan(x)) = sec^2(x)/tan(x)"
"7) d(c)/d(x) = 2/3(x)+4     d(x)/d(t)  = .04t+.03   =  (2/3(x)+4 ) * (.04t+.03) = 2/3(.04 t+.03) + 4 \
t=4  , 8/75 + 1/50 + 4 = 4.13"
# Out:
# '7) d(c)/d(x) = 2/3(x)+4     d(x)/d(t)  = .04t+.03   =  (2/3(x)+4 ) * (.04t+.03) = 2/3(.04 t+.03) + 4 t=4  , 8/75 + 1/50 + 4 = 4.13'

# %% [markdown]
# ## Integrals
#
# The integral is essentially the opposite of the derivative. But first, there are 2 flavors of integrals: indefinite and definite integrals. An indefinite integral returns an function; a definite integral returns a number.

# %% [markdown]
# #### Indefinite integrals:
# An indefinite integral simply reverses a derivative.
# $$\int \dfrac{dG}{dx}dx = G(x) + C$$
# Here is another notation. Notice that $f(x)$ denotes the function that is being integrated and $F(x)$ is the answer.
# $$\int f(x)dx = F(x) + C$$
#
# _Example_:
# What is the integral of cosine: $cos(x)$?
# $$\int cos(x) dx = sin(x) + C$$
# Remember: in an indefinite integral, we _always_ add a constant ( + C) add the end of the resulting function because the derivative of a constant is 0. Hence, any $\frac {d} {dx} [sin(x) + 1] = \frac {d} {dx} [sin(x) + 2] =  \frac {d} {dx} [sin(x) - 100000000] = cos(x)$

# %% [markdown]
# #### Definite integrals:
# The difference between an indefinite and definite integral is that a definite integral has upper and lower bounds. Geometrically, for an indefinite integral on a function $f(x)$, we get a (family of) function $F(x)$. For a definite integral, we are looking at the area bounded by the curve $f(x)$ and the x-axis. Note, area can be negative if a large portion of the area is below the x-axis.
#
# The integral of the derivative over an interval is exactly **the difference in values of the function at the interval boundary points.**
# $$\int_{a}^{b}\dfrac{dG}{dx}dx = G(b)-G(a)$$
#
# Another notation is
# $$\int_{a}^{b} f(x)dx = F(b)-F(a)$$
#
# In simplier words, for an indefinite integral, we first take the indefinite integral and then  put the upper bound number into the resulting function to get an actual number (let's call it _num1_). Then, we do the same for the lower bound number to get another number (_num2_). Lastly, we subtract the 2 resulting numbers to get the answer (num1 - num2).

# %% [markdown]
# #### Your turn:
#
# 1. $\int x dx$
# 2. $\int x^3 dx$
#
# 3. $\int sin(x) dx$
# 4. $\int_{-\pi}^{\pi} sin(x) dx$
# 5. $\int_{-\pi / 2}^{\pi / 2} cos(x) dx$

# %% [markdown]
# Congrats! You finished a good portion of calculus. More review in the next lesson.

# %%
"1) x^2/2+c"
"2)x^4/4 +c"
"3) -cos(x)"
"4)-cos(pi) + (cos(-pi)) = 1 + (-1) = 0"
"5)sin(pi/2) - sin(-pi/2) ="
